# %%
pip install vaderSentiment
# Out:
# ...
#      -------------------------------------- 126.0/126.0 kB 2.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords if not already downloaded
nltk.download('stopwords')

# Load the dataset
data = pd.read_csv("C:/Users/ayush/Downloads/budget_2021.csv")

# Function to preprocess text
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove mentions (@usernames)
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    # Remove punctuations
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove extra whitespace
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Apply preprocessing to the dataset
data['cleaned_text'] = data['text'].apply(preprocess_text)

# Remove duplicate rows based on the 'cleaned_text' column
data.drop_duplicates(subset='cleaned_text', inplace=True)

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment and its value
def get_sentiment_and_value(text):
    sentiment_dict = analyzer.polarity_scores(text)
    sentiment_value = sentiment_dict['compound']
    
    # Determine the categorical sentiment label
    if sentiment_value >= 0.05:
        sentiment_label = 'Positive'
    elif sentiment_value <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    
    return sentiment_label, sentiment_value

# Apply sentiment analysis to the cleaned text
data[['sentiment', 'sentiment_value']] = data['cleaned_text'].apply(lambda x: pd.Series(get_sentiment_and_value(x)))

# Save the result to a new CSV file
data.to_csv('budget_2021_with_sentiment.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords if not already downloaded
nltk.download('stopwords')

# Load the dataset
data = pd.read_csv("C:/Users/ayush/Downloads/budget_2022.csv")

# Function to preprocess text
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove mentions (@usernames)
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    # Remove punctuations
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove extra whitespace
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Apply preprocessing to the dataset
data['cleaned_text'] = data['text'].apply(preprocess_text)

# Remove duplicate rows based on the 'cleaned_text' column
data.drop_duplicates(subset='cleaned_text', inplace=True)

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment and its value
def get_sentiment_and_value(text):
    sentiment_dict = analyzer.polarity_scores(text)
    sentiment_value = sentiment_dict['compound']
    
    # Determine the categorical sentiment label
    if sentiment_value >= 0.05:
        sentiment_label = 'Positive'
    elif sentiment_value <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    
    return sentiment_label, sentiment_value

# Apply sentiment analysis to the cleaned text
data[['sentiment', 'sentiment_value']] = data['cleaned_text'].apply(lambda x: pd.Series(get_sentiment_and_value(x)))

# Save the result to a new CSV file
data.to_csv('budget_2022_with_sentiment.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords if not already downloaded
nltk.download('stopwords')

# Load the dataset
data = pd.read_csv("C:/Users/ayush/Downloads/budget_2023.csv")

# Function to preprocess text
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove mentions (@usernames)
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    # Remove punctuations
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove extra whitespace
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Apply preprocessing to the dataset
data['cleaned_text'] = data['text'].apply(preprocess_text)

# Remove duplicate rows based on the 'cleaned_text' column
data.drop_duplicates(subset='cleaned_text', inplace=True)

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment and its value
def get_sentiment_and_value(text):
    sentiment_dict = analyzer.polarity_scores(text)
    sentiment_value = sentiment_dict['compound']
    
    # Determine the categorical sentiment label
    if sentiment_value >= 0.05:
        sentiment_label = 'Positive'
    elif sentiment_value <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    
    return sentiment_label, sentiment_value

# Apply sentiment analysis to the cleaned text
data[['sentiment', 'sentiment_value']] = data['cleaned_text'].apply(lambda x: pd.Series(get_sentiment_and_value(x)))

# Save the result to a new CSV file
data.to_csv('budget_2023_with_sentiment.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
